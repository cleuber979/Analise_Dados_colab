# %% [markdown]
# <a href="https://colab.research.google.com/github/cleuber979/Analise_Dados_colab/blob/main/Introdu%C3%A7%C3%A3o_Pandas_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #passo a passo importação de bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ##leitura do arquivo

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Vendas_Pneus.xlsx')

# %% [markdown]
# vê o que tem dentro do meu DataFrame

# %%
df
# Out:
#    Vendas mês  Michelin  Pirelli  Continental  Goodyear  Bridgestone    Kumho  \
# 0     Janeiro    150000   132000       122140    122210       122214   125256
# 1   fevereiro    145000    98000       152222     85000       122564   122556
# 2       Março    132251   152000       142241    132250       122245   133325
# 3       Abril    159000   154000       154325    123250       122144   112935
# 4       Maio     180000   122000       144120     12000        85654    65215
# 5      Junho      90000   100200        75000    125220       112251   123222
# 6       Julho    110000   170000       154352    113445       144332   122256
# 7      Agosto    134210   122214       140155    116222       125225    85010
# 8    Setembro    195000    85000       113321     75250       122548   122215
# 9    Outubro     120000   122420       110218    123556       132225   144450
# 10   Novembro     85215   145000       153210    114221       145985   155225
# ...

# %% [markdown]
# ##vejo só os 5 primeiros arquivos

# %%
df.head()
# Out:
#   Vendas mês  Michelin  Pirelli  Continental  Goodyear  Bridgestone   Kumho  \
# 0    Janeiro    150000   132000       122140    122210       122214  125256
# 1  fevereiro    145000    98000       152222     85000       122564  122556
# 2      Março    132251   152000       142241    132250       122245  133325
# 3      Abril    159000   154000       154325    123250       122144  112935
# 4      Maio     180000   122000       144120     12000        85654   65215
#
#    Firestone  Dunlop
# 0     122221  122252
# 1     122221  124556
# 2     144441  155211
# 3     122235  155222
# 4     122245   75854

# %% [markdown]
# ##vejo os 5 ultimos arquivos

# %%
df.tail()
# Out:
#    Vendas mês  Michelin  Pirelli  Continental  Goodyear  Bridgestone    Kumho  \
# 8    Setembro    195000    85000       113321     75250       122548   122215
# 9    Outubro     120000   122420       110218    123556       132225   144450
# 10   Novembro     85215   145000       153210    114221       145985   155225
# 11  Dezembro     149651   112222       132222    122210       122256   122221
# 12      Total   1650327  1515056      1593526   1264834      1479643  1433886
#
#     Firestone   Dunlop
# 8      122215   120102
# 9      124445   120140
# 10     122214    14569
# 11     135155   120120
# 12    1419872  1296924

# %% [markdown]
# ##enteder o que tem dentro do meu DataSet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Vendas mês   13 non-null     object
#  1   Michelin     13 non-null     int64
#  2   Pirelli      13 non-null     int64
#  3   Continental  13 non-null     int64
#  4   Goodyear     13 non-null     int64
#  5   Bridgestone  13 non-null     int64
#  6   Kumho        13 non-null     int64
#  7   Firestone    13 non-null     int64
#  8   Dunlop       13 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 1.0+ KB

# %% [markdown]
# ## .info() me tras o que as entradas a quantidades de entradas se tem alguma celula nula e os tipos de variaveis e a informação de cada colunas

# %%
df.isna().sum()
# Out:
# Vendas mês     0
# Michelin       0
# Pirelli        0
# Continental    0
# Goodyear       0
# Bridgestone    0
# Kumho          0
# Firestone      0
# Dunlop         0
# dtype: int64

# %% [markdown]
# o comando .isna() retorna a quantidade de colunas nulas para auxiliar temos o comando sum() que soma as linhas nulas que eu tenho, no exemplo acima não temos nenhuma linha nula

# %%
df.dtypes
# Out:
# Vendas mês     object
# Michelin        int64
# Pirelli         int64
# Continental     int64
# Goodyear        int64
# Bridgestone     int64
# Kumho           int64
# Firestone       int64
# Dunlop          int64
# dtype: object

# %% [markdown]
# O comando .dtypes re outra forma de retorna os tipos de variaveis

# %%
df['Michelin']>85215
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# Name: Michelin, dtype: bool

# %% [markdown]
# ## indica que no mês 10 eu não tive uma venda superior 85215 deste valor
